# %% [markdown]
# # <img src="ups.png">
#
# ### Nombre: Fanny Gutama
# ### Docente: Ing. Diego Quisi
#
# ## Simulador Sympy Parte2.

# %% [markdown]
# # Entornos de soporte al desarrollo de simulaciones: Simpy - Parte 2
#
#
# ## Generacion de graficar de atencion.
#
# En base a la simulacion anterior generar una grafica de los autos atendidos.

# %%
import simpy
import random
import matplotlib.pyplot as pp

# %matplotlib inline

# Maximo de vehiculos que puede recibir el negocio
MAX_VEHICULOS = 57
# Total de maquinas de lavado con que cuenta el negocio
NUM_MAQUINAS = 3
# Tiempo que tarda en lavarse un vehiculo (minutos)
TIEMPO_LAVADO = 10 
# Intervalo de tiempo en que llegan vehiculos (minutos)
INTERVALO_LLEGADA = 3
# Tiempo de simulación
TIEMPO_SIMULACION = 27

# Creamos un diccionario para almacenar las horas en que se lavan los vehiculos
tiempo={}

class Lavanderia(object):
    
    def __init__(self, environment, num_maquinas, tiempo_lavado):
        # Guardamos como variable el entorno de ejecucion
        self.env=environment
        # Creamos el recurso que representa las maquinas
        self.maquinas = simpy.Resource(environment, num_maquinas)
        # Variable para el tiempo de lavado
        self.tiempo_lavado = tiempo_lavado
        
    def lavar_vehiculo(self, vehiculo):
        # Este metodo representa el proceso de lavado del vehículo.
        # Se ingresa el vehículo y se lava
        
        # Simulamos el tiempo que tarda en lavarse el vehiculo
        # Es importante notar que la instruccion "yield" es distinta de "sleep"
        # ya que esta ultima bloquea el hilo de ejecucion durante 't' unidades de tiempo,
        # mientras que 'yield' no bloquea el hilo de ejecucion, solo lo suspende mientras
        # el evento de 'lavado' se realice
        yield self.env.timeout(random.randint(TIEMPO_LAVADO-5, TIEMPO_LAVADO+5))
        
        # Simulamos que se ha limpiado parte (%) de la suciedad del vehiculo
        # Para el % generamos un entero entre 30 y 90
        print('Removido  {%d%%} suciedad vehiculo => %s ' % (random.randint(30,90), vehiculo))
        
    
def llegada_vehiculo(env, nombre, lavanderia):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega el vehiculo con el nombre pasado como parametro
    print('Llega vehiculo: %s a la hora %.2f.' % (nombre, env.now))
    
    # Especificamos que vamos a usar un recurso (Resource) que representa
    # la maquina de lavado
    with lavanderia.maquinas.request() as maquina:
        # Ocupamos la maquina de lavado
        yield maquina
        # Indicamos que vehiculo entra a la lavanderia
        print('Entra vehiculo a lavarse: %s a la hora %.2f.' % (nombre, env.now))
        # Procesamos la operacion de lavado
        yield env.process(lavanderia.lavar_vehiculo(nombre))
        # Una vez que termina la llamada con 'yield', se indica que se ha lavado el vehiculo
        print('Vehiculo [%s] lavado a las %.2f.' % (nombre, env.now))

       
        tiempo[nombre]=env.now
        
    
def ejecutar_simulacion(env, num_maquinas, tiempo_lavado, intervalo):
    lavanderia=Lavanderia(env, num_maquinas, tiempo_lavado)
    # Creamos 5 llegadas de vehiculos iniciales
    for i in range(5):
        env.process(llegada_vehiculo(env, 'Vehiculo-%d'%(i+1),lavanderia))
    
    # Ejecutamos la simulacion
    while True:
        yield env.timeout(random.randint(intervalo-3, intervalo+3))
        i+=1
        # Mientras se lavan los vehiculos generamos mas vehiculos
        env.process(llegada_vehiculo(env,'Vehiculo-%d'%(i+1),lavanderia))

print('Lavanderia UPS')

# Creamos el entorno de simulacion
env=simpy.Environment()
env.process(ejecutar_simulacion(env, NUM_MAQUINAS, TIEMPO_LAVADO, INTERVALO_LLEGADA))

# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)


print("Diccionario timepo :")
print(tiempo)

# %%
# Generamos la grafica
datos=sorted(tiempo.items()) # Ordenamos los datos
x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
pp.title("Vehiculos Atenndidos X Tiempo")
pp.grid(True) #Generamos una cuadricula
pp.show() #Mostramos el grafico

# %%
import simpy
import random
import matplotlib.pyplot as pp

# Maximo de vehiculos que puede recibir el negocio
MAX_VEHICULOS = 57 
# Total de maquinas de lavado con que cuenta el negocio
NUM_MAQUINAS = 3
# Tiempo que tarda en trasladarse un vehiculo (minutos)
TRASLADO_BUS = 4
TRASLADO_AUTOMOVIL= 1
TRASLADO_FURGONETA= 2
# Tiempo que tarda en lavarse un vehiculo (minutos)
TIEMPO_BUS = 20
TIEMPO_AUTOMOVIL= 7
TIEMPO_FURGONETA= 12
# Intervalo de tiempo en que llegan vehiculos (minutos)
INTERVALO_LLEGADA = 10
# Tiempo de simulación
TIEMPO_SIMULACION = 100

# Creamos un diccionario para almacenar las horas en que se lavan los vehiculos
tiempo={}

class Lavanderia(object):
    
    def __init__(self, environment, num_maquinas,tiempo_bus,tiempo_automovil,
                 tiempo_furgoneta,traslado_bus,traslado_automovil,traslado_furgoneta):
        # Guardamos como variable el entorno de ejecucion
        self.env=environment
        # Creamos el recurso que representa las maquinas
        self.maquinas = simpy.Resource(environment, num_maquinas)
        # Variable para el tiempo de lavado
        self.tiempo_bus = tiempo_bus
        self.tiempo_automovil = tiempo_automovil
        self.tiempo_furgoneta = tiempo_furgoneta
        self.traslado_bus = traslado_bus
        self.traslado_automovil = traslado_automovil
        self.traslado_furgoneta = traslado_furgoneta
        
    def lavar_vehiculo(self, vehiculo):
        automotor=vehiculo.split('-')
        if(automotor[0] == 'Bus'):
            yield self.env.timeout(TIEMPO_BUS)
        if(automotor[0] == 'Automovil'):
            yield self.env.timeout(TIEMPO_AUTOMOVIL)
        if(automotor[0] == 'Furgoneta'):
            yield self.env.timeout(TIEMPO_FURGONETA)
        #Solo agregamos al diccionario al momento que termina de lavar el vehiculo.
        k=automotor[0]
        if k in tiempo:
            tiempo[k]=tiempo[k]+1
        else:
            tiempo[k]=1
            
        # Simulamos que se ha limpiado parte (%) de la suciedad del vehiculo
        # Para el % generamos un entero entre 30 y 90
        print('Removido  {%d%%} suciedad vehiculo => %s ' %(random.randint(30,90), vehiculo))
        
    def trasladar_vehiculo(self, vehiculo):
        automotor=vehiculo.split('-')
        if(automotor[0] == 'Bus'):
            yield self.env.timeout(TRASLADO_BUS)
        if(automotor[0] == 'Automovil'):
            yield self.env.timeout(TRASLADO_AUTOMOVIL)
        if(automotor[0] == 'Furgoneta'):
            yield self.env.timeout(TRASLADO_FURGONETA)
       
    
def llegada_vehiculo(env, nombre, lavanderia):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega el vehiculo con el nombre pasado como parametro
    print('Llega vehiculo: %s a la hora %.2f.' % (nombre, env.now))
    
    # Especificamos que vamos a usar un recurso (Resource) que representa
    # la maquina de lavado
    with lavanderia.maquinas.request() as maquina:
        # Ocupamos la maquina de lavado
        yield maquina
        #Indicamos que el vehiculo se esta trasladando para ser lavado
        print('Se traslada vehiculo: %s a la hora %.2f.' % (nombre,env.now))
        #Procesamos el traslado del vehiculo
        yield env.process(lavanderia.trasladar_vehiculo(nombre))
        # Indicamos que vehiculo entra a la lavanderia
        print('Entra vehiculo a lavarse: %s a la hora %.2f.' % (nombre, env.now))
        # Procesamos la operacion de lavado
        yield env.process(lavanderia.lavar_vehiculo(nombre))
        # Una vez que termina la llamada con 'yield', se indica que se ha lavado el vehiculo
        print('Vehiculo [%s] lavado a las %.2f.' % (nombre, env.now))  
        
def ejecutar_simulacion(env, num_maquinas, tiempo_bus,tiempo_automovil,
                        tiempo_furgoneta,traslado_bus,traslado_automovil,
                        traslado_furgoneta, intervalo):
    lavanderia=Lavanderia(env, num_maquinas, tiempo_bus,tiempo_automovil,
                          tiempo_furgoneta,traslado_bus,traslado_automovil,
                          traslado_furgoneta)
    # Creamos 5 llegadas de vehiculos iniciales
    for i in range(2):
        env.process(llegada_vehiculo(env, 'Bus-%d'%(i+1),lavanderia))
        env.process(llegada_vehiculo(env, 'Automovil-%d'%(i+1),lavanderia))
        env.process(llegada_vehiculo(env, 'Furgoneta-%d'%(i+1),lavanderia))
        
    # Ejecutamos la simulacion
    while True:
        yield env.timeout(random.randint(intervalo-3, intervalo+3))
        i+=1
        # Mientras se lavan los vehiculos generamos mas vehiculos
        rnd = random.randint(1,100)
        if rnd <= 20: # Bus 20%, Furgoneta 30% y Automovil 50%
            env.process(llegada_vehiculo(env,'Bus-%d'%(i+1),lavanderia))
        elif rnd <= 50:
            env.process(llegada_vehiculo(env,'Furgoneta-%d'%(i+1),lavanderia))
        else:
            env.process(llegada_vehiculo(env,'Automovil-%d'%(i+1),lavanderia))

print('Lavanderia UPS')

# Creamos el entorno de simulacion
env=simpy.Environment()
env.process(ejecutar_simulacion(env, NUM_MAQUINAS, TIEMPO_BUS,TIEMPO_AUTOMOVIL,
                                TIEMPO_FURGONETA,TRASLADO_BUS,TRASLADO_AUTOMOVIL,
                                TRASLADO_FURGONETA, INTERVALO_LLEGADA))
# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)

# Generamos la grafica
datos=sorted(tiempo.items())
x, y =zip(*datos)
pp.plot(x,y,linewidth=2,color='red')
pp.scatter(x,y,color='blue')
pp.grid(True)
pp.show()

# %% [markdown]
# ## Paremetrizando la simulacion
#
# * Considerar 3 tipos de vehículos con 3 diferentes tiempos de lavado:
#     * Bus: 20 minutos
#     * Automóvil: 7 minutos
#     * Furgoneta: 12 minutos
# * Considere que a partir de la entrada del vehículo para ser lavado, deberán tomarse en cuenta los siguientes tiempos correspondientes al proceso de traslado desde la recepción a la máquina de lavado:
#     * Bus: 4 minutos
#     * Automóvil: 1 minuto
#     * Furgoneta: 2 minutos
# * Realice una gráfica de la simulación con 3 máquinas de lavado

# %% [markdown]
# ## Práctica  Sympy 2
#
# En base a la simulacion, generar una simulacion lo mas apegado a la realidad del Covid-19, para ello obtener informacion del numero de consultorios y camas disponibles en un hospital del Ecuador. Parametrizar la simulacion para ingresar el numero de pacientes, el numero de consultorios y el numero de camas y algun otro parametro que considere oportuno.
#
# Finalmente generar las siguientes metricas :
# - Tiempo de espera promedio para cada sala.
# - Tiempo promedio total que requiere un paciente para ser atendido desde cero.
# - Cuántos pacientes se atendieron.
# - Cuántos pacientes se quedaron sin atender y fallecieron.

# %%
import simpy
import random
import matplotlib.pyplot as pp
import numpy as np
from time import sleep
from progress.bar import Bar
# %matplotlib inline
from tqdm.notebook import trange, tqdm
from time import sleep

# %%
contagiados = 100
tiempoConsulta = 15  
internado = 10
simulacion = 10

#Diccionario para almacenar los resultados
recuperados={}
muertos={}
tConsultas=[]
TiempoEsperaConsultorio=[]
pacienteMuertosSinAntencionM=[]
pacientesAtendidos=[]

class SimulacionHospSTereza(object):
    #constructor
    def __init__(self, env, num_cama,num_consultorios, name):
            self.env = env
            self.num_cama = num_cama
            self.num_consultorios=num_consultorios
            self.camas = simpy.Resource(env, num_cama)
            self.consultorios=simpy.Resource(env, num_consultorios)
            self.name = name
    def ingresarConsultorio(self,paciente):
        consulta=random.uniform(tiempoConsulta-0.5, tiempoConsulta+0.5)
        yield self.env.timeout(consulta)
        print("El paciente ", paciente, " espero", int(consulta*1440), "minutos para se atendido")
        tConsultas.append(consulta)
        
    def PacienteCama(self, paciente):
        yield self.env.timeout(random.randint(internado-1.0, internado+1.0))
        print("El paciente ", paciente, " fue internado el día ", int(self.env.now))

def llegada_paciente(env, hospital, paciente):
    arrive = env.now
    with hospital.consultorios.request() as consultorio:
        esperandoConsulta=random.randint(1,3)
        TiempoEsperaConsultorio.append(esperandoConsulta)
        reque2 = yield consultorio | env.timeout(esperandoConsulta)
        espera2 = env.now - arrive
        if consultorio in reque2:
            print("Al paciente: ", paciente, "Se le ubica en una sala con cama.")
            yield env.process(hospital.ingresarConsultorio(paciente))
            estado = random.randint(1,100)
            pacientesAtendidos.append(1)
            if(estado < 40):
                with hospital.camas.request() as cama:
                    arrive2 = env.now
                    dias_esperando = random.randint(1,5) 
                    requerimiento = yield cama | env.timeout(dias_esperando) # tiempo de espera
                    espera = env.now - arrive2
                    if cama in requerimiento:
                        print("Al paciente: ", paciente, " se le asigna una cama")
                        yield env.process(hospital.PacienteCama(paciente))
                        estado = random.randint(1,100)
                        if (estado < 8) :
                            muertos[env.now] = muertos[env.now] + 1 if env.now in muertos else  1
                        else:
                            recuperados[env.now] = recuperados[env.now] + 1 if env.now in recuperados else 1
                    else:
                        print("El paciente " , paciente, " espero ", int(espera) , " dias y fallece por la falta de camas")
                        muertos[env.now] = muertos[env.now] + 1 if env.now in muertos else  1
            else :
                print("El paciente ", paciente, " no tiene COVID-19" )
        else:
            print("El paciente " , paciente, "espero ", int(espera2) ," dias y fallece porque no fue atendido")
            pacienteMuertosSinAntencionM.append(1)
            muertos[env.now] = muertos[env.now] + 1 if env.now in muertos else  1
def run(env, tasacrecimiento, infectados):
    numeroCamas= 42
    numeroConsultorios = 20
    hospSTereza = SimulacionHospSTereza(env, numeroCamas,numeroConsultorios, "Madre Domelia denominado Hospital COVID 1")
    for i in range(infectados):
        asignar_hospital(env, hospSTereza, i)
    paciente = infectados
    while True:
        yield env.timeout(1)
        for i in range(tasacrecimiento):
            paciente += 1
            asignar_hospital(env, hospSTereza, paciente)
                
def asignar_hospital(env, hospSTereza, paciente):
    hosp_esc = 1
    if (hosp_esc == 1):
        print("Llega un paciente nuevo: ", paciente, "Madre Domelia denominado Hospital COVID 1")
        env.process(llegada_paciente(env, hospSTereza, paciente))

    
print("Inicio Simulacion Covid-19 Albania")
entrada = int(input("ESCRIBA VALOR DE CRECIMIENTO: "))
env=simpy.Environment()
env.process(run(env,entrada, contagiados))
env.run(until=simulacion)
for i in trange(simulacion, desc='===>'):
    for j in tqdm(range(3), desc='==>'):
        sleep(0.001)

datos=sorted(muertos.items())
x, y =zip(*datos)
pp.plot(x,y,linewidth=2,color='y')
pp.scatter(x,y,color='g')
pp.title("Personas Fallecidas  / dias de hospitalizacion")
pp.grid(True)
pp.show()
print("---------------------------------------------- :")
print('RESULTADOS')
print("Recuperados: ")
print(round(sum(muertos)))
print("Fallecidos: ")
print(round(sum(recuperados)))
# Out:
# Inicio Simulacion Covid-19 Albania
# ESCRIBA VALOR DE CRECIMIENTO: 10
# Llega un paciente nuevo:  0 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  1 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  2 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  3 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  4 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  5 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  6 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  7 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  8 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  9 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  10 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  11 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  12 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  13 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  14 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  15 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  16 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  17 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  18 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  19 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  20 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  21 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  22 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  23 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  24 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  25 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  26 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  27 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  28 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  29 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  30 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  31 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  32 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  33 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  34 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  35 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  36 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  37 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  38 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  39 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  40 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  41 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  42 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  43 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  44 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  45 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  46 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  47 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  48 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  49 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  50 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  51 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  52 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  53 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  54 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  55 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  56 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  57 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  58 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  59 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  60 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  61 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  62 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  63 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  64 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  65 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  66 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  67 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  68 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  69 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  70 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  71 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  72 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  73 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  74 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  75 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  76 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  77 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  78 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  79 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  80 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  81 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  82 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  83 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  84 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  85 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  86 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  87 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  88 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  89 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  90 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  91 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  92 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  93 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  94 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  95 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  96 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  97 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  98 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  99 Madre Domelia denominado Hospital COVID 1
# Al paciente:  0 Se le ubica en una sala con cama.
# Al paciente:  1 Se le ubica en una sala con cama.
# Al paciente:  2 Se le ubica en una sala con cama.
# Al paciente:  3 Se le ubica en una sala con cama.
# Al paciente:  4 Se le ubica en una sala con cama.
# Al paciente:  5 Se le ubica en una sala con cama.
# Al paciente:  6 Se le ubica en una sala con cama.
# Al paciente:  7 Se le ubica en una sala con cama.
# Al paciente:  8 Se le ubica en una sala con cama.
# Al paciente:  9 Se le ubica en una sala con cama.
# Al paciente:  10 Se le ubica en una sala con cama.
# Al paciente:  11 Se le ubica en una sala con cama.
# Al paciente:  12 Se le ubica en una sala con cama.
# Al paciente:  13 Se le ubica en una sala con cama.
# Al paciente:  14 Se le ubica en una sala con cama.
# Al paciente:  15 Se le ubica en una sala con cama.
# Al paciente:  16 Se le ubica en una sala con cama.
# Al paciente:  17 Se le ubica en una sala con cama.
# Al paciente:  18 Se le ubica en una sala con cama.
# Al paciente:  19 Se le ubica en una sala con cama.
# Llega un paciente nuevo:  101 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  102 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  103 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  104 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  105 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  106 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  107 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  108 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  109 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  110 Madre Domelia denominado Hospital COVID 1
# El paciente  26 espero  1  dias y fallece porque no fue atendido
# El paciente  29 espero  1  dias y fallece porque no fue atendido
# El paciente  32 espero  1  dias y fallece porque no fue atendido
# El paciente  41 espero  1  dias y fallece porque no fue atendido
# El paciente  46 espero  1  dias y fallece porque no fue atendido
# El paciente  49 espero  1  dias y fallece porque no fue atendido
# El paciente  50 espero  1  dias y fallece porque no fue atendido
# El paciente  51 espero  1  dias y fallece porque no fue atendido
# El paciente  58 espero  1  dias y fallece porque no fue atendido
# El paciente  60 espero  1  dias y fallece porque no fue atendido
# El paciente  61 espero  1  dias y fallece porque no fue atendido
# El paciente  63 espero  1  dias y fallece porque no fue atendido
# El paciente  64 espero  1  dias y fallece porque no fue atendido
# El paciente  66 espero  1  dias y fallece porque no fue atendido
# El paciente  67 espero  1  dias y fallece porque no fue atendido
# El paciente  69 espero  1  dias y fallece porque no fue atendido
# El paciente  72 espero  1  dias y fallece porque no fue atendido
# El paciente  73 espero  1  dias y fallece porque no fue atendido
# El paciente  75 espero  1  dias y fallece porque no fue atendido
# El paciente  77 espero  1  dias y fallece porque no fue atendido
# El paciente  83 espero  1  dias y fallece porque no fue atendido
# El paciente  87 espero  1  dias y fallece porque no fue atendido
# El paciente  89 espero  1  dias y fallece porque no fue atendido
# El paciente  90 espero  1  dias y fallece porque no fue atendido
# El paciente  96 espero  1  dias y fallece porque no fue atendido
# El paciente  97 espero  1  dias y fallece porque no fue atendido
# Llega un paciente nuevo:  111 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  112 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  113 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  114 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  115 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  116 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  117 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  118 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  119 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  120 Madre Domelia denominado Hospital COVID 1
# El paciente  21 espero  2  dias y fallece porque no fue atendido
# El paciente  23 espero  2  dias y fallece porque no fue atendido
# El paciente  24 espero  2  dias y fallece porque no fue atendido
# El paciente  25 espero  2  dias y fallece porque no fue atendido
# El paciente  33 espero  2  dias y fallece porque no fue atendido
# El paciente  35 espero  2  dias y fallece porque no fue atendido
# El paciente  36 espero  2  dias y fallece porque no fue atendido
# El paciente  37 espero  2  dias y fallece porque no fue atendido
# El paciente  39 espero  2  dias y fallece porque no fue atendido
# El paciente  40 espero  2  dias y fallece porque no fue atendido
# El paciente  42 espero  2  dias y fallece porque no fue atendido
# El paciente  45 espero  2  dias y fallece porque no fue atendido
# El paciente  47 espero  2  dias y fallece porque no fue atendido
# El paciente  53 espero  2  dias y fallece porque no fue atendido
# El paciente  55 espero  2  dias y fallece porque no fue atendido
# El paciente  56 espero  2  dias y fallece porque no fue atendido
# El paciente  62 espero  2  dias y fallece porque no fue atendido
# El paciente  65 espero  2  dias y fallece porque no fue atendido
# El paciente  74 espero  2  dias y fallece porque no fue atendido
# El paciente  76 espero  2  dias y fallece porque no fue atendido
# El paciente  78 espero  2  dias y fallece porque no fue atendido
# El paciente  79 espero  2  dias y fallece porque no fue atendido
# El paciente  80 espero  2  dias y fallece porque no fue atendido
# El paciente  81 espero  2  dias y fallece porque no fue atendido
# El paciente  82 espero  2  dias y fallece porque no fue atendido
# El paciente  84 espero  2  dias y fallece porque no fue atendido
# El paciente  86 espero  2  dias y fallece porque no fue atendido
# El paciente  88 espero  2  dias y fallece porque no fue atendido
# El paciente  91 espero  2  dias y fallece porque no fue atendido
# El paciente  94 espero  2  dias y fallece porque no fue atendido
# El paciente  98 espero  2  dias y fallece porque no fue atendido
# El paciente  99 espero  2  dias y fallece porque no fue atendido
# El paciente  103 espero  1  dias y fallece porque no fue atendido
# El paciente  105 espero  1  dias y fallece porque no fue atendido
# El paciente  109 espero  1  dias y fallece porque no fue atendido
# Llega un paciente nuevo:  121 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  122 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  123 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  124 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  125 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  126 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  127 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  128 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  129 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  130 Madre Domelia denominado Hospital COVID 1
# El paciente  20 espero  3  dias y fallece porque no fue atendido
# El paciente  22 espero  3  dias y fallece porque no fue atendido
# El paciente  27 espero  3  dias y fallece porque no fue atendido
# El paciente  28 espero  3  dias y fallece porque no fue atendido
# El paciente  30 espero  3  dias y fallece porque no fue atendido
# El paciente  31 espero  3  dias y fallece porque no fue atendido
# El paciente  34 espero  3  dias y fallece porque no fue atendido
# El paciente  38 espero  3  dias y fallece porque no fue atendido
# El paciente  43 espero  3  dias y fallece porque no fue atendido
# El paciente  44 espero  3  dias y fallece porque no fue atendido
# El paciente  48 espero  3  dias y fallece porque no fue atendido
# El paciente  52 espero  3  dias y fallece porque no fue atendido
# El paciente  54 espero  3  dias y fallece porque no fue atendido
# El paciente  57 espero  3  dias y fallece porque no fue atendido
# El paciente  59 espero  3  dias y fallece porque no fue atendido
# El paciente  68 espero  3  dias y fallece porque no fue atendido
# El paciente  70 espero  3  dias y fallece porque no fue atendido
# El paciente  71 espero  3  dias y fallece porque no fue atendido
# El paciente  85 espero  3  dias y fallece porque no fue atendido
# El paciente  92 espero  3  dias y fallece porque no fue atendido
# El paciente  93 espero  3  dias y fallece porque no fue atendido
# El paciente  95 espero  3  dias y fallece porque no fue atendido
# El paciente  102 espero  2  dias y fallece porque no fue atendido
# El paciente  104 espero  2  dias y fallece porque no fue atendido
# El paciente  107 espero  2  dias y fallece porque no fue atendido
# El paciente  112 espero  1  dias y fallece porque no fue atendido
# El paciente  116 espero  1  dias y fallece porque no fue atendido
# El paciente  118 espero  1  dias y fallece porque no fue atendido
# El paciente  119 espero  1  dias y fallece porque no fue atendido
# Llega un paciente nuevo:  131 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  132 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  133 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  134 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  135 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  136 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  137 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  138 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  139 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  140 Madre Domelia denominado Hospital COVID 1
# El paciente  101 espero  3  dias y fallece porque no fue atendido
# El paciente  106 espero  3  dias y fallece porque no fue atendido
# El paciente  108 espero  3  dias y fallece porque no fue atendido
# El paciente  110 espero  3  dias y fallece porque no fue atendido
# El paciente  113 espero  2  dias y fallece porque no fue atendido
# El paciente  115 espero  2  dias y fallece porque no fue atendido
# El paciente  117 espero  2  dias y fallece porque no fue atendido
# El paciente  122 espero  1  dias y fallece porque no fue atendido
# El paciente  123 espero  1  dias y fallece porque no fue atendido
# El paciente  127 espero  1  dias y fallece porque no fue atendido
# El paciente  129 espero  1  dias y fallece porque no fue atendido
# Llega un paciente nuevo:  141 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  142 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  143 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  144 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  145 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  146 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  147 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  148 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  149 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  150 Madre Domelia denominado Hospital COVID 1
# El paciente  111 espero  3  dias y fallece porque no fue atendido
# El paciente  114 espero  3  dias y fallece porque no fue atendido
# El paciente  120 espero  3  dias y fallece porque no fue atendido
# El paciente  121 espero  2  dias y fallece porque no fue atendido
# El paciente  128 espero  2  dias y fallece porque no fue atendido
# El paciente  132 espero  1  dias y fallece porque no fue atendido
# El paciente  133 espero  1  dias y fallece porque no fue atendido
# El paciente  134 espero  1  dias y fallece porque no fue atendido
# El paciente  136 espero  1  dias y fallece porque no fue atendido
# Llega un paciente nuevo:  151 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  152 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  153 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  154 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  155 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  156 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  157 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  158 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  159 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  160 Madre Domelia denominado Hospital COVID 1
# El paciente  124 espero  3  dias y fallece porque no fue atendido
# El paciente  125 espero  3  dias y fallece porque no fue atendido
# El paciente  126 espero  3  dias y fallece porque no fue atendido
# El paciente  130 espero  3  dias y fallece porque no fue atendido
# El paciente  131 espero  2  dias y fallece porque no fue atendido
# El paciente  135 espero  2  dias y fallece porque no fue atendido
# El paciente  138 espero  2  dias y fallece porque no fue atendido
# El paciente  140 espero  2  dias y fallece porque no fue atendido
# El paciente  141 espero  1  dias y fallece porque no fue atendido
# El paciente  144 espero  1  dias y fallece porque no fue atendido
# El paciente  147 espero  1  dias y fallece porque no fue atendido
# El paciente  148 espero  1  dias y fallece porque no fue atendido
# Llega un paciente nuevo:  161 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  162 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  163 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  164 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  165 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  166 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  167 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  168 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  169 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  170 Madre Domelia denominado Hospital COVID 1
# El paciente  137 espero  3  dias y fallece porque no fue atendido
# El paciente  139 espero  3  dias y fallece porque no fue atendido
# El paciente  142 espero  2  dias y fallece porque no fue atendido
# El paciente  146 espero  2  dias y fallece porque no fue atendido
# El paciente  157 espero  1  dias y fallece porque no fue atendido
# El paciente  158 espero  1  dias y fallece porque no fue atendido
# El paciente  159 espero  1  dias y fallece porque no fue atendido
# El paciente  160 espero  1  dias y fallece porque no fue atendido
# Llega un paciente nuevo:  171 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  172 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  173 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  174 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  175 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  176 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  177 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  178 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  179 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  180 Madre Domelia denominado Hospital COVID 1
# El paciente  143 espero  3  dias y fallece porque no fue atendido
# El paciente  145 espero  3  dias y fallece porque no fue atendido
# El paciente  149 espero  3  dias y fallece porque no fue atendido
# El paciente  150 espero  3  dias y fallece porque no fue atendido
# El paciente  151 espero  2  dias y fallece porque no fue atendido
# El paciente  152 espero  2  dias y fallece porque no fue atendido
# El paciente  154 espero  2  dias y fallece porque no fue atendido
# El paciente  156 espero  2  dias y fallece porque no fue atendido
# El paciente  161 espero  1  dias y fallece porque no fue atendido
# El paciente  165 espero  1  dias y fallece porque no fue atendido
# Llega un paciente nuevo:  181 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  182 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  183 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  184 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  185 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  186 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  187 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  188 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  189 Madre Domelia denominado Hospital COVID 1
# Llega un paciente nuevo:  190 Madre Domelia denominado Hospital COVID 1
# El paciente  153 espero  3  dias y fallece porque no fue atendido
# El paciente  155 espero  3  dias y fallece porque no fue atendido
# El paciente  162 espero  2  dias y fallece porque no fue atendido
# El paciente  163 espero  2  dias y fallece porque no fue atendido
# El paciente  164 espero  2  dias y fallece porque no fue atendido
# El paciente  166 espero  2  dias y fallece porque no fue atendido
# El paciente  169 espero  2  dias y fallece porque no fue atendido
# El paciente  171 espero  1  dias y fallece porque no fue atendido
# El paciente  173 espero  1  dias y fallece porque no fue atendido
# El paciente  175 espero  1  dias y fallece porque no fue atendido
# El paciente  180 espero  1  dias y fallece porque no fue atendido
# HBox(children=(FloatProgress(value=0.0, description='===>', max=10.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='==>', max=3.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='==>', max=3.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='==>', max=3.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='==>', max=3.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='==>', max=3.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='==>', max=3.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='==>', max=3.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='==>', max=3.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='==>', max=3.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='==>', max=3.0, style=ProgressStyle(description_width='ini…
# ---------------------------------------------- :
# RESULTADOS
# Recuperados:
# 45
# Fallecidos:
# 0

# %%
print("Tiempo promedio en la sala de espera")
r= round(int(sum(tConsultas)/len(tConsultas)*3600)/1000)
print('==>',r, " minutos")

print("Tiempo promedio para que una persona sea atendida desde su llegada al hospital")
s = (int(2*(sum(TiempoEsperaConsultorio)/len(TiempoEsperaConsultorio))))
print('==>',s," horas")

print("Numero de pacientes atendidos")
t = sum(pacientesAtendidos)
print('==>',t)

print("Pacientes sin atencion medica y fallecieron")
print('==>',sum(pacienteMuertosSinAntencionM))
x2=[r,s,t]
y=[r,s,t] 
pp.plot(x,y,linewidth=1.5,color='black')
pp.scatter(x2,y, color=['y','green','grey'],s=20**2)
pp.legend(x2,loc="upper left", title="color")
pp.title("Grafica de tiempo ")
pp.grid(True)
pp.show()

# %% [markdown]
# ## Referencias
# [1] Matloff, N. (2008). Introduction to Discrete-Event Simulation and the SimPy Language.
#
# [2] Team Simpy (2017). SimPy Documentation, Release 3.0.10, 2017. URL: https://media.readthedocs.org/pdf/simpy/latest/simpy.pdf
